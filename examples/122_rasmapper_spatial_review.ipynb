# %% [markdown]
# # RASMapper Spatial Review

# %%
from pathlib import Path
import json
import re
import time

import pandas as pd
from IPython.display import Image, Markdown, display

from ras_commander import RasExamples, RasMap, RasPrj
import ras_commander

pd.set_option("display.max_columns", 80)
pd.set_option("display.max_colwidth", 120)

# RASMapper screenshot cells require Windows + a local HEC-RAS/RASMapper install.
# Leave this True for the full visual demonstration.
CAPTURE_SNAPSHOTS = True
RAS_VERSION = "6.6"
SNAPSHOT_TIMEOUT_SECONDS = 1800  # 30 minutes for large projects that open slowly.
SNAPSHOT_DELAY_SECONDS = 8
RUN_LOW_LEVEL_CAPTURE = False  # Optional extra demo of open/capture/close primitives.

RUN_ROOT = Path.cwd() / "working" / "notebook_runs" / "122_rasmapper_spatial_review"
PROJECT_NAMES = [
    "Balde Eagle Creek",
    "Muncie",
    "BaldEagleCrkMulti2D",
    "Davis",
    "NewOrleansMetro",
]

print(f"ras-commander: {ras_commander.__version__}")
print(f"Run folder: {RUN_ROOT}")
print(f"Capture snapshots: {CAPTURE_SNAPSHOTS}")

# %% [markdown]
# ## Developer Mode
#
# The committed notebook imports `ras_commander` normally. For local source development, install the repository in editable mode before running:
#
# ```powershell
# uv pip install -e .
# ```
#
# Generated example projects, screenshots, and review bundles are written under `working/notebook_runs/` or each extracted project's `RASMapper Screenshots` folder, not under `examples/`.

# %% [markdown]
# # RASMapper Spatial Review and Screenshot Workflows
#
# This notebook demonstrates the `RasMap` APIs for controlling RASMapper state, launching standalone `RasMapper.exe`, capturing screenshots, and building repeatable spatial QA/QC evidence bundles.
#
# The examples intentionally use several real `RasExamples` projects:
#
# - **Balde Eagle Creek**: 1D cross-section and structure layers.
# - **Muncie**: terrain, land-cover/map layers, 2D flow areas, and structures.
# - **BaldEagleCrkMulti2D**: multiple geometries with differing 2D elements, breaklines, and SA/2D connections.
# - **Davis**: urban storm system with pipes, pumps, storage, and 2D areas.
# - **NewOrleansMetro**: large 2D surface model with pipes, pumps, breaklines, and SA/2D structures.
#
# `RasMap.create_spatial_review_package()` writes to a project subfolder named **RASMapper Screenshots** by default. The notebook displays generated PNGs inline after each capture.

# %% [markdown]
# ## API Coverage
#
# This notebook touches the main RASMapper automation surface:
#
# - Layer discovery: `parse_rasmap`, `list_map_layers`, `list_reference_map_layers`, `list_basemap_layers`, `list_standard_basemap_layers`, `list_terrain_layers`, `list_landcover_layers`, `list_soils_layers`, `list_infiltration_layers`, `list_geometry_layers`, `list_result_layers`, `list_geometry_features`.
# - Layer mutation: `add_reference_map_layer`, `add_basemap_layer`, `set_map_layer_visibility`, `set_terrain_layer_visibility`, `set_geometry_layer_visibility`, `set_result_layer_visibility`, `set_update_legend_with_view`.
# - View and bounds: `get_current_view`, `set_current_view`, `get_geometry_layer_bounds`, `get_geometry_feature_bounds`, `zoom_to_geometry_layer`.
# - Window/screenshot workflows: `open_rasmapper`, `capture_rasmapper_snapshot`, `close_rasmapper`, and the higher-level `create_spatial_review_package`.

# %%
RUN_ROOT.mkdir(parents=True, exist_ok=True)

extracted = RasExamples.extract_project(
    PROJECT_NAMES,
    output_path=RUN_ROOT,
    suffix="rasmapper_demo",
)
projects = dict(zip(PROJECT_NAMES, extracted))

project_table = pd.DataFrame(
    [
        {
            "example_name": name,
            "project_path": str(path),
            "rasmap_files": ", ".join(p.name for p in sorted(Path(path).glob("*.rasmap"))),
        }
        for name, path in projects.items()
    ]
)
display(project_table)
# Out:
# 2026-06-26 19:38:39 - ras_commander.RasExamples - INFO - Successfully extracted project 'Balde Eagle Creek' to <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Balde Eagle Creek_rasmapper_demo
# 2026-06-26 19:38:40 - ras_commander.RasExamples - INFO - Successfully extracted project 'Muncie' to <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Muncie_rasmapper_demo
# 2026-06-26 19:38:41 - ras_commander.RasExamples - INFO - Successfully extracted project 'BaldEagleCrkMulti2D' to <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagleCrkMulti2D_rasmapper_demo
# 2026-06-26 19:38:41 - ras_commander.RasExamples - INFO - Successfully extracted project 'Davis' to <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Davis_rasmapper_demo
# 2026-06-26 19:38:41 - ras_commander.RasExamples - INFO - Downloading special project from: https://www.hec.usace.army.mil/confluence/rasdocs/hgt/files/latest/299502039/299502111/1/1747692522764/NewOrleansMetroPipesExample.zip
# 2026-06-26 19:38:41 - ras_commander.RasExamples - INFO - This may take a few moments...
# 2026-06-26 19:38:51 - ras_commander.RasExamples - INFO - Downloaded special project zip file to <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\NewOrleansMetro_rasmapper_demo_temp.zip
# 2026-06-26 19:38:52 - ras_commander.RasExamples - INFO - Successfully extracted special project 'NewOrleansMetro' to <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\NewOrleansMetro_rasmapper_demo
#           example_name  \
# 0    Balde Eagle Creek
# 1               Muncie
# 2  BaldEagleCrkMulti2D
# 3                Davis
# 4      NewOrleansMetro
#
#                                                                                                               project_path  \
# 0  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Balde Ea...
# 1  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Muncie_r...
# 2  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 3  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Davis_ra...
# 4  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\NewOrlea...
#
#               rasmap_files
# 0         BaldEagle.rasmap
# 1            Muncie.rasmap
# 2   BaldEagleDamBrk.rasmap
# 3  DavisStormSystem.rasmap
# 4   NewOrleansMetro.rasmap

# %%
def slugify(value: str) -> str:
    return re.sub(r"[^A-Za-z0-9_.-]+", "_", value).strip("_")


def compact_display(df: pd.DataFrame, columns=None, max_rows: int = 12):
    if df is None or df.empty:
        display(pd.DataFrame())
        return
    view = df.copy()
    if columns is not None:
        view = view[[c for c in columns if c in view.columns]]
    display(view.head(max_rows))


def first_terrain_name(project_path: Path, preferred: str | None = None) -> str | None:
    terrains = RasMap.list_terrain_layers(project_path)
    if terrains.empty:
        return None
    if preferred and preferred in set(terrains["name"]):
        return preferred
    checked = terrains.loc[terrains["checked"].fillna(False)]
    if not checked.empty:
        return checked.iloc[0]["name"]
    return terrains.iloc[0]["name"]


def maybe_map_category(project_path: Path, preferred):
    layers = RasMap.list_map_layers(project_path)
    if layers.empty:
        return None
    categories = set(layers["category"].dropna())
    preferred_values = [preferred] if isinstance(preferred, str) else list(preferred or [])
    selected = [value for value in preferred_values if value in categories]
    return selected or None


def display_snapshot(state: dict):
    snapshot = state.get("snapshot", {})
    path = snapshot.get("path")
    if path and snapshot.get("created"):
        display(Markdown(f"**Screenshot:** `{path}`"))
        display(Image(filename=path))
    else:
        display(Markdown(
            "No screenshot was created. "
            f"Requested: `{snapshot.get('requested')}`; error: `{snapshot.get('error')}`"
        ))


def create_demo_review(
    project_name: str,
    *,
    title: str,
    geometry_number: str,
    layer_type,
    terrain_name: str | None = None,
    feature_index: int | None = None,
    map_layer_category=None,
    include_results: bool = False,
    include_map_layers: bool = False,
) -> dict:
    project_path = Path(projects[project_name])
    snapshot_filename = f"{slugify(title)}.png"
    state = RasMap.create_spatial_review_package(
        project_path,
        geometry_number=geometry_number,
        layer_type=layer_type,
        feature_index=feature_index,
        terrain_name=terrain_name,
        map_layer_category=map_layer_category,
        include_results=include_results,
        include_map_layers=include_map_layers,
        capture_snapshot=CAPTURE_SNAPSHOTS,
        snapshot_filename=snapshot_filename,
        delay_seconds=SNAPSHOT_DELAY_SECONDS,
        snapshot_timeout_seconds=SNAPSHOT_TIMEOUT_SECONDS,
        ras_version=RAS_VERSION,
        require_snapshot=False,
    )
    assert Path(state["output_dir"]).name == "RASMapper Screenshots"
    display(Markdown(f"### {title}"))
    display(Markdown(f"Project: `{project_path}`"))
    display(Markdown(f"Review folder: `{state['output_dir']}`"))
    display(pd.DataFrame(state["preflight"])[["code", "passed", "message"]])
    display_snapshot(state)
    return state

# %% [markdown]
# ## Project Inventory
#
# Start by reading the `.rasmap` files into DataFrames. The inventory carries each file's parse status and field-error count alongside its layer counts, so an unreadable file cannot look like a valid project with zero layers.

# %%
inventory_rows = []
catalogs = {}

for name, project_path in projects.items():
    project_path = Path(project_path)
    project_file = RasPrj.find_ras_prj(project_path)
    expected_rasmap = (
        project_file.with_suffix(".rasmap")
        if project_file is not None
        else project_path / f"{project_path.name}.rasmap"
    )
    rasmap_file = next(project_path.glob("*.rasmap"), expected_rasmap)
    rasmap_df = RasMap.parse_rasmap(rasmap_file)
    rasmap_summary = rasmap_df.iloc[0]
    if rasmap_summary["rasmap_status"] in {"parsed", "parsed_with_errors"}:
        map_layers = RasMap.list_map_layers(rasmap_file)
        terrain_layers = RasMap.list_terrain_layers(rasmap_file)
        landcover_layers = RasMap.list_landcover_layers(rasmap_file)
        soils_layers = RasMap.list_soils_layers(rasmap_file)
        infiltration_layers = RasMap.list_infiltration_layers(rasmap_file)
        geometry_layers = RasMap.list_geometry_layers(rasmap_file)
        result_layers = RasMap.list_result_layers(rasmap_file)
        current_view = RasMap.get_current_view(rasmap_file)
    else:
        map_layers = pd.DataFrame(columns=["category"])
        terrain_layers = pd.DataFrame()
        landcover_layers = pd.DataFrame()
        soils_layers = pd.DataFrame()
        infiltration_layers = pd.DataFrame()
        geometry_layers = pd.DataFrame(columns=["category"])
        result_layers = pd.DataFrame()
        current_view = {}

    catalogs[name] = {
        "rasmap_df": rasmap_df,
        "map_layers": map_layers,
        "terrain_layers": terrain_layers,
        "landcover_layers": landcover_layers,
        "soils_layers": soils_layers,
        "infiltration_layers": infiltration_layers,
        "geometry_layers": geometry_layers,
        "result_layers": result_layers,
        "current_view": current_view,
    }

    inventory_rows.append(
        {
            "project": name,
            "rasmap_status": rasmap_summary["rasmap_status"],
            "rasmap_field_error_count": len(rasmap_summary["rasmap_field_errors"]),
            "terrains": len(terrain_layers),
            "map_layers": len(map_layers),
            "reference_layers": int((map_layers.get("category", pd.Series(dtype=str)) == "reference").sum()) if not map_layers.empty else 0,
            "basemaps": int((map_layers.get("category", pd.Series(dtype=str)) == "basemap").sum()) if not map_layers.empty else 0,
            "landcover_layers": len(landcover_layers),
            "soils_layers": len(soils_layers),
            "infiltration_layers": len(infiltration_layers),
            "geometry_tree_rows": len(geometry_layers),
            "result_tree_rows": len(result_layers),
            "current_view_min_x": current_view.get("min_x"),
            "current_view_max_x": current_view.get("max_x"),
        }
    )

inventory = pd.DataFrame(inventory_rows)
display(inventory)

# %%
for name in PROJECT_NAMES:
    display(Markdown(f"### {name}: geometry elements"))
    geometry_layers = catalogs[name]["geometry_layers"]
    compact_display(
        geometry_layers.loc[geometry_layers["category"].eq("geometry_element")],
        columns=["geometry_number", "geometry_name", "layer_name", "layer_type", "checked", "geometry_hdf_exists"],
        max_rows=20,
    )
# Out:
# ### Balde Eagle Creek: geometry elements
#    geometry_number                   geometry_name            layer_name  \
# 1               01  Existing Conditions - GIS Data
# 2               01  Existing Conditions - GIS Data        Culvert Groups
# 3               01  Existing Conditions - GIS Data       Culvert Barrels
# 4               01  Existing Conditions - GIS Data           Gate Groups
# 5               01  Existing Conditions - GIS Data         Gate Openings
# 6               01  Existing Conditions - GIS Data        Culvert Groups
# 7               01  Existing Conditions - GIS Data       Culvert Barrels
# 8               01  Existing Conditions - GIS Data  Rating Curve Outlets
# 9               01  Existing Conditions - GIS Data    Outlet Time Series
# 10              01  Existing Conditions - GIS Data           Gate Groups
# 11              01  Existing Conditions - GIS Data         Gate Openings
# 12              01  Existing Conditions - GIS Data        Culvert Groups
# 13              01  Existing Conditions - GIS Data       Culvert Barrels
# 14              01  Existing Conditions - GIS Data  Rating Curve Outlets
# 15              01  Existing Conditions - GIS Data    Outlet Time Series
# 16              01  Existing Conditions - GIS Data           Gate Groups
# 17              01  Existing Conditions - GIS Data         Gate Openings
# 18              01  Existing Conditions - GIS Data        Culvert Groups
# 19              01  Existing Conditions - GIS Data       Culvert Barrels
# 20              01  Existing Conditions - GIS Data  Rating Curve Outlets
#
#                      layer_type checked  geometry_hdf_exists
# 1                         RASXS    None                 True
# 2   VirtualGeometryFeatureLayer    None                 True
# 3   VirtualGeometryFeatureLayer    None                 True
# 4   VirtualGeometryFeatureLayer    None                 True
# 5   VirtualGeometryFeatureLayer    None                 True
# 6   VirtualGeometryFeatureLayer    None                 True
# 7   VirtualGeometryFeatureLayer    None                 True
# 8   VirtualGeometryFeatureLayer    None                 True
# 9   VirtualGeometryFeatureLayer    None                 True
# 10  VirtualGeometryFeatureLayer    None                 True
# 11  VirtualGeometryFeatureLayer    None                 True
# 12  VirtualGeometryFeatureLayer    None                 True
# 13  VirtualGeometryFeatureLayer    None                 True
# 14  VirtualGeometryFeatureLayer    None                 True
# 15  VirtualGeometryFeatureLayer    None                 True
# 16  VirtualGeometryFeatureLayer    None                 True
# 17  VirtualGeometryFeatureLayer    None                 True
# 18  VirtualGeometryFeatureLayer    None                 True
# 19  VirtualGeometryFeatureLayer    None                 True
# 20  VirtualGeometryFeatureLayer    None                 True
# ### Muncie: geometry elements
#    geometry_number                 geometry_name            layer_name  \
# 1               01  Muncie Base Geometry - 9 SAs
# 2               01  Muncie Base Geometry - 9 SAs
# 3               01  Muncie Base Geometry - 9 SAs
# 4               01  Muncie Base Geometry - 9 SAs
# 5               01  Muncie Base Geometry - 9 SAs
# 6               01  Muncie Base Geometry - 9 SAs        Culvert Groups
# 7               01  Muncie Base Geometry - 9 SAs       Culvert Barrels
# 8               01  Muncie Base Geometry - 9 SAs           Gate Groups
# 9               01  Muncie Base Geometry - 9 SAs         Gate Openings
# 10              01  Muncie Base Geometry - 9 SAs        Culvert Groups
# 11              01  Muncie Base Geometry - 9 SAs       Culvert Barrels
# 12              01  Muncie Base Geometry - 9 SAs  Rating Curve Outlets
# 13              01  Muncie Base Geometry - 9 SAs    Outlet Time Series
# 14              01  Muncie Base Geometry - 9 SAs           Gate Groups
# 15              01  Muncie Base Geometry - 9 SAs         Gate Openings
# 16              01  Muncie Base Geometry - 9 SAs        Culvert Groups
# 17              01  Muncie Base Geometry - 9 SAs       Culvert Barrels
# 18              01  Muncie Base Geometry - 9 SAs  Rating Curve Outlets
# 19              01  Muncie Base Geometry - 9 SAs    Outlet Time Series
# 20              01  Muncie Base Geometry - 9 SAs           Gate Groups
#
#                      layer_type checked  geometry_hdf_exists
# 1                      RASRiver    True                 True
# 2                  RASBankLines    True                 True
# 3                         RASXS    True                 True
# 4                  RASEdgeLines    True                 True
# 5            MeshPerimeterLayer    None                 True
# 6   VirtualGeometryFeatureLayer    None                 True
# 7   VirtualGeometryFeatureLayer    None                 True
# 8   VirtualGeometryFeatureLayer    None                 True
# 9   VirtualGeometryFeatureLayer    None                 True
# 10  VirtualGeometryFeatureLayer    None                 True
# 11  VirtualGeometryFeatureLayer    None                 True
# 12  VirtualGeometryFeatureLayer    None                 True
# 13  VirtualGeometryFeatureLayer    None                 True
# 14  VirtualGeometryFeatureLayer    None                 True
# 15  VirtualGeometryFeatureLayer    None                 True
# 16  VirtualGeometryFeatureLayer    None                 True
# 17  VirtualGeometryFeatureLayer    None                 True
# 18  VirtualGeometryFeatureLayer    None                 True
# 19  VirtualGeometryFeatureLayer    None                 True
# 20  VirtualGeometryFeatureLayer    None                 True
# ### BaldEagleCrkMulti2D: geometry elements
#    geometry_number              geometry_name            layer_name  \
# 1               06  Bald Eagle Multi 2D Areas
# 2               06  Bald Eagle Multi 2D Areas
# 3               06  Bald Eagle Multi 2D Areas                    XS
# 4               06  Bald Eagle Multi 2D Areas
# 5               06  Bald Eagle Multi 2D Areas
# 6               06  Bald Eagle Multi 2D Areas
# 7               06  Bald Eagle Multi 2D Areas        Culvert Groups
# 8               06  Bald Eagle Multi 2D Areas       Culvert Barrels
# 9               06  Bald Eagle Multi 2D Areas           Gate Groups
# 10              06  Bald Eagle Multi 2D Areas         Gate Openings
# 11              06  Bald Eagle Multi 2D Areas        Culvert Groups
# 12              06  Bald Eagle Multi 2D Areas       Culvert Barrels
# 13              06  Bald Eagle Multi 2D Areas  Rating Curve Outlets
# 14              06  Bald Eagle Multi 2D Areas    Outlet Time Series
# 15              06  Bald Eagle Multi 2D Areas           Gate Groups
# 16              06  Bald Eagle Multi 2D Areas         Gate Openings
# 17              06  Bald Eagle Multi 2D Areas        Culvert Groups
# 18              06  Bald Eagle Multi 2D Areas       Culvert Barrels
# 19              06  Bald Eagle Multi 2D Areas  Rating Curve Outlets
# 20              06  Bald Eagle Multi 2D Areas    Outlet Time Series
#
#                      layer_type checked  geometry_hdf_exists
# 1                      RASRiver    True                 True
# 2                   RASJunction    True                 True
# 3                         RASXS    True                 True
# 4                RASStorageArea    True                 True
# 5                 RASD2FlowArea    True                 True
# 6            MeshPerimeterLayer    None                 True
# 7   VirtualGeometryFeatureLayer    None                 True
# 8   VirtualGeometryFeatureLayer    None                 True
# 9   VirtualGeometryFeatureLayer    None                 True
# 10  VirtualGeometryFeatureLayer    None                 True
# 11  VirtualGeometryFeatureLayer    None                 True
# 12  VirtualGeometryFeatureLayer    None                 True
# 13  VirtualGeometryFeatureLayer    None                 True
# 14  VirtualGeometryFeatureLayer    None                 True
# 15  VirtualGeometryFeatureLayer    None                 True
# 16  VirtualGeometryFeatureLayer    None                 True
# 17  VirtualGeometryFeatureLayer    None                 True
# 18  VirtualGeometryFeatureLayer    None                 True
# 19  VirtualGeometryFeatureLayer    None                 True
# 20  VirtualGeometryFeatureLayer    None                 True
# ### Davis: geometry elements
#    geometry_number              geometry_name            layer_name  \
# 1               02  Davis Full System w_ Pump
# 2               02  Davis Full System w_ Pump
# 3               02  Davis Full System w_ Pump
# 4               02  Davis Full System w_ Pump
# 5               02  Davis Full System w_ Pump
# 6               02  Davis Full System w_ Pump
# 7               02  Davis Full System w_ Pump
# 8               02  Davis Full System w_ Pump        Culvert Groups
# 9               02  Davis Full System w_ Pump       Culvert Barrels
# 10              02  Davis Full System w_ Pump           Gate Groups
# 11              02  Davis Full System w_ Pump         Gate Openings
# 12              02  Davis Full System w_ Pump        Culvert Groups
# 13              02  Davis Full System w_ Pump       Culvert Barrels
# 14              02  Davis Full System w_ Pump  Rating Curve Outlets
# 15              02  Davis Full System w_ Pump    Outlet Time Series
# 16              02  Davis Full System w_ Pump           Gate Groups
# 17              02  Davis Full System w_ Pump         Gate Openings
# 18              02  Davis Full System w_ Pump        Culvert Groups
# 19              02  Davis Full System w_ Pump       Culvert Barrels
# 20              02  Davis Full System w_ Pump  Rating Curve Outlets
#
#                      layer_type checked  geometry_hdf_exists
# 1                      RASRiver    None                 True
# 2                   RASJunction    None                 True
# 3                         RASXS    None                 True
# 4                RASStorageArea    None                 True
# 5                 RASD2FlowArea    True                 True
# 6            MeshPerimeterLayer    True                 True
# 7                MeshPointLayer    True                 True
# 8   VirtualGeometryFeatureLayer    None                 True
# 9   VirtualGeometryFeatureLayer    None                 True
# 10  VirtualGeometryFeatureLayer    None                 True
# 11  VirtualGeometryFeatureLayer    None                 True
# 12  VirtualGeometryFeatureLayer    None                 True
# 13  VirtualGeometryFeatureLayer    None                 True
# 14  VirtualGeometryFeatureLayer    None                 True
# 15  VirtualGeometryFeatureLayer    None                 True
# 16  VirtualGeometryFeatureLayer    None                 True
# 17  VirtualGeometryFeatureLayer    None                 True
# 18  VirtualGeometryFeatureLayer    None                 True
# 19  VirtualGeometryFeatureLayer    None                 True
# 20  VirtualGeometryFeatureLayer    None                 True
# ### NewOrleansMetro: geometry elements
#    geometry_number             geometry_name            layer_name  \
# 1               02  2D Surface Model w Pipes
# 2               02  2D Surface Model w Pipes
# 3               02  2D Surface Model w Pipes
# 4               02  2D Surface Model w Pipes
# 5               02  2D Surface Model w Pipes
# 6               02  2D Surface Model w Pipes
# 7               02  2D Surface Model w Pipes
# 8               02  2D Surface Model w Pipes        Culvert Groups
# 9               02  2D Surface Model w Pipes       Culvert Barrels
# 10              02  2D Surface Model w Pipes           Gate Groups
# 11              02  2D Surface Model w Pipes         Gate Openings
# 12              02  2D Surface Model w Pipes        Culvert Groups
# 13              02  2D Surface Model w Pipes       Culvert Barrels
# 14              02  2D Surface Model w Pipes  Rating Curve Outlets
# 15              02  2D Surface Model w Pipes    Outlet Time Series
# 16              02  2D Surface Model w Pipes           Gate Groups
# 17              02  2D Surface Model w Pipes         Gate Openings
# 18              02  2D Surface Model w Pipes        Culvert Groups
# 19              02  2D Surface Model w Pipes       Culvert Barrels
# 20              02  2D Surface Model w Pipes  Rating Curve Outlets
#
#                      layer_type checked  geometry_hdf_exists
# 1                      RASRiver    None                 True
# 2                   RASJunction    None                 True
# 3                         RASXS    None                 True
# 4                RASStorageArea    None                 True
# 5                 RASD2FlowArea    True                 True
# 6            MeshPerimeterLayer    None                 True
# 7                 RASBreakLines    True                 True
# 8   VirtualGeometryFeatureLayer    None                 True
# 9   VirtualGeometryFeatureLayer    None                 True
# 10  VirtualGeometryFeatureLayer    None                 True
# 11  VirtualGeometryFeatureLayer    None                 True
# 12  VirtualGeometryFeatureLayer    None                 True
# 13  VirtualGeometryFeatureLayer    None                 True
# 14  VirtualGeometryFeatureLayer    None                 True
# 15  VirtualGeometryFeatureLayer    None                 True
# 16  VirtualGeometryFeatureLayer    None                 True
# 17  VirtualGeometryFeatureLayer    None                 True
# 18  VirtualGeometryFeatureLayer    None                 True
# 19  VirtualGeometryFeatureLayer    None                 True
# 20  VirtualGeometryFeatureLayer    None                 True

# %% [markdown]
# ## Map Layers: Add, List, Validate, and Toggle
#
# The Muncie example is a convenient place to demonstrate map-layer management. The notebook creates a tiny WGS84 GeoJSON reference layer, rejects a projected GeoJSON, adds a standard basemap, and then uses layer-state controls to build figure context.

# %%
muncie = Path(projects["Muncie"])
gis_dir = muncie / "GIS_Data"
gis_dir.mkdir(exist_ok=True)

good_geojson = gis_dir / "rasmapper_demo_wgs84.geojson"
good_geojson.write_text(
    json.dumps(
        {
            "type": "FeatureCollection",
            "features": [
                {
                    "type": "Feature",
                    "properties": {"name": "RASMapper demo polygon"},
                    "geometry": {
                        "type": "Polygon",
                        "coordinates": [[
                            [-85.43, 40.18],
                            [-85.42, 40.18],
                            [-85.42, 40.19],
                            [-85.43, 40.19],
                            [-85.43, 40.18],
                        ]],
                    },
                }
            ],
        }
    ),
    encoding="utf-8",
)

bad_geojson = gis_dir / "rasmapper_demo_projected.geojson"
bad_geojson.write_text(
    json.dumps(
        {
            "type": "FeatureCollection",
            "crs": {"type": "name", "properties": {"name": "EPSG:3857"}},
            "features": [
                {
                    "type": "Feature",
                    "properties": {"name": "Projected demo polygon"},
                    "geometry": {
                        "type": "Polygon",
                        "coordinates": [[[1000000, 5000000], [1001000, 5000000], [1001000, 5001000], [1000000, 5001000], [1000000, 5000000]]],
                    },
                }
            ],
        }
    ),
    encoding="utf-8",
)

display(RasMap.list_standard_basemap_layers())

RasMap.add_reference_map_layer(muncie, good_geojson, layer_name="Demo WGS84 GeoJSON")
try:
    RasMap.add_reference_map_layer(muncie, bad_geojson, layer_name="Demo Projected GeoJSON")
except ValueError as exc:
    display(Markdown(f"Projected GeoJSON rejected as expected: `{exc}`"))

RasMap.add_basemap_layer(muncie, "USGS Topo", checked=True)

display(Markdown("### Muncie map layers after edits"))
compact_display(
    RasMap.list_map_layers(muncie),
    columns=["name", "type", "category", "checked", "filename", "exists"],
    max_rows=30,
)

display(Markdown("### Reference layers"))
compact_display(RasMap.list_reference_map_layers(muncie), columns=["name", "type", "checked", "filename", "exists"])

display(Markdown("### Basemap layers"))
compact_display(RasMap.list_basemap_layers(muncie), columns=["name", "type", "checked", "filename", "is_standard_basemap"])
# Out:
#                            name      type  \
# 0                 Google Hybrid  WMSLayer
# 1                Bing Satellite  WMSLayer
# 2       ArcGIS NatGeo World Map  WMSLayer
# 3          ArcGIS USA Topo Maps  WMSLayer
# 4  Google Terrain Streets Water  WMSLayer
# 5                OpenStreetMaps  WMSLayer
# 6                  USGS Imagery  WMSLayer
# 7                     USGS Topo  WMSLayer
#
#                                                               filename  \
# 0                 %LocalAppData%\HEC\Mapping\5.1\XML\Google Hybrid.xml
# 1                %LocalAppData%\HEC\Mapping\5.1\XML\Bing Satellite.xml
# 2       %LocalAppData%\HEC\Mapping\5.1\XML\ArcGIS NatGeo World Map.xml
# 3          %LocalAppData%\HEC\Mapping\5.1\XML\ArcGIS USA Topo Maps.xml
# 4  %LocalAppData%\HEC\Mapping\5.1\XML\Google Terrain Streets Water.xml
# 5                %LocalAppData%\HEC\Mapping\5.1\XML\OpenStreetMaps.xml
# 6                  %LocalAppData%\HEC\Mapping\5.1\XML\USGS Imagery.xml
# 7                     %LocalAppData%\HEC\Mapping\5.1\XML\USGS Topo.xml
#
#   resample_method
# 0            near
# 1            near
# 2            near
# 3            near
# 4            near
# 5            near
# 6            near
# 7            near
# 2026-06-26 19:38:52 - ras_commander._rasmap_layer_helper - INFO - Added reference map layer 'Demo WGS84 GeoJSON' to <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Muncie_rasmapper_demo\Muncie.rasmap
# Projected GeoJSON rejected as expected: `GeoJSON source must be WGS84/EPSG:4326 for RASMapper: <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Muncie_rasmapper_demo\GIS_Data\rasmapper_demo_projected.geojson. Coordinate bounds look projected, not lon/lat: (1000000.0, 5000000.0, 1001000.0, 5001000.0)`
# 2026-06-26 19:38:52 - ras_commander._rasmap_layer_helper - INFO - Added basemap layer 'USGS Topo' to <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Muncie_rasmapper_demo\Muncie.rasmap
# ### Muncie map layers after edits
# 2026-06-26 19:38:52 - ras_commander.RasMap - INFO - Found 5 map layers in .rasmap
#                  name                 type             category  checked  \
# 0          Land Cover       LandCoverLayer  land_classification    False
# 1   LandCoverUSGSGrid       LandCoverLayer  land_classification    False
# 2   LandCoverCombined       LandCoverLayer  land_classification    False
# 3  Demo WGS84 GeoJSON  PolygonFeatureLayer            reference     True
# 4           USGS Topo             WMSLayer              basemap     True
#
#                                            filename  exists
# 0            .\LandCover\LandCoverUserShapefile.hdf    True
# 1                 .\LandCover\LandCoverUSGSGrid.hdf    True
# 2                 .\LandCover\LandCoverCombined.hdf    True
# 3           .\GIS_Data\rasmapper_demo_wgs84.geojson    True
# 4  %LocalAppData%\HEC\Mapping\5.1\XML\USGS Topo.xml    True
# ### Reference layers
#                  name                 type  checked  \
# 3  Demo WGS84 GeoJSON  PolygonFeatureLayer     True
#
#                                   filename  exists
# 3  .\GIS_Data\rasmapper_demo_wgs84.geojson    True
# ### Basemap layers
#         name      type  checked  \
# 4  USGS Topo  WMSLayer     True
#
#                                            filename  is_standard_basemap
# 4  %LocalAppData%\HEC\Mapping\5.1\XML\USGS Topo.xml                 True

# %%
# Visibility controls are useful before launching RASMapper for figures.
RasMap.set_map_layer_visibility(muncie, checked=False)
RasMap.set_map_layer_visibility(muncie, category=["land_classification", "reference"], checked=True, exclusive=True)
RasMap.set_terrain_layer_visibility(muncie, terrain_name=first_terrain_name(muncie, "TerrainWithChannel"), checked=True, exclusive=True)
RasMap.set_update_legend_with_view(muncie, include_map_layers=True)

display(Markdown("### Visible map layers after figure-state setup"))
visible_maps = RasMap.list_map_layers(muncie)
compact_display(
    visible_maps.loc[visible_maps["checked"].fillna(False)],
    columns=["name", "category", "type", "checked"],
    max_rows=30,
)
# Out:
# ### Visible map layers after figure-state setup
# 2026-06-26 19:38:53 - ras_commander.RasMap - INFO - Found 5 map layers in .rasmap
#                  name             category                 type  checked
# 0          Land Cover  land_classification       LandCoverLayer     True
# 1   LandCoverUSGSGrid  land_classification       LandCoverLayer     True
# 2   LandCoverCombined  land_classification       LandCoverLayer     True
# 3  Demo WGS84 GeoJSON            reference  PolygonFeatureLayer     True

# %%
# Give the 1D Bald Eagle Creek screenshot a standard basemap for visual context.
# The other examples already have useful terrain or map context, so leave them unchanged.
balde_eagle = Path(projects["Balde Eagle Creek"])
if RasMap.list_basemap_layers(balde_eagle).empty:
    RasMap.add_basemap_layer(balde_eagle, "USGS Topo", checked=False)

basemap_summary = []
for name, project_path in projects.items():
    basemaps = RasMap.list_basemap_layers(project_path)
    basemap_summary.append({"project": name, "basemap_count": len(basemaps), "basemap_names": basemaps["name"].tolist() if not basemaps.empty else []})

display(pd.DataFrame(basemap_summary))
# Out:
# 2026-06-26 19:38:53 - ras_commander._rasmap_layer_helper - INFO - Added basemap layer 'USGS Topo' to <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Balde Eagle Creek_rasmapper_demo\BaldEagle.rasmap
#                project  basemap_count    basemap_names
# 0    Balde Eagle Creek              1      [USGS Topo]
# 1               Muncie              1      [USGS Topo]
# 2  BaldEagleCrkMulti2D              1  [Google Hybrid]
# 3                Davis              0               []
# 4      NewOrleansMetro              1  [Google Hybrid]

# %% [markdown]
# ## Bounds and Feature Discovery
#
# Geometry-layer screenshots are driven from compiled geometry HDF extents. Feature selectors do not hide individual features; they only center the view on one feature and zoom out for context.

# %%
multi2d = Path(projects["BaldEagleCrkMulti2D"])
multi_layers = RasMap.list_geometry_layers(multi2d)
multi_g03 = multi_layers.loc[
    (multi_layers["geometry_number"] == "03")
    & (multi_layers["category"] == "geometry_element")
]
display(multi_g03[["layer_id", "layer_name", "layer_type", "checked", "geometry_hdf_path"]])

g03_hdf = Path(multi_g03["geometry_hdf_path"].dropna().iloc[0])
for layer_type in ["RASD2FlowArea", "RASBreakLines", "SA2DStructureLayer", "RASXS"]:
    bounds = RasMap.get_geometry_layer_bounds(g03_hdf, layer_type=layer_type)
    display(Markdown(f"**{layer_type} bounds**"))
    display(pd.DataFrame([bounds]))
    features = RasMap.list_geometry_features(g03_hdf, layer_type=layer_type)
    compact_display(features, columns=["layer_type", "feature_index", "feature_name", "feature_type", "min_x", "min_y", "max_x", "max_y"], max_rows=8)
# Out:
#                                                                       layer_id  \
# 244                                                   geometry:8:layer:0:RASXS
# 245                                           geometry:8:layer:1:RASD2FlowArea
# 246                                      geometry:8:layer:2:MeshPerimeterLayer
# 247                                          geometry:8:layer:3:MeshPointLayer
# 248                                           geometry:8:layer:4:RASBreakLines
# 249                                         geometry:8:layer:5:MeshRegionLayer
# 250              geometry:8:layer:6:VirtualGeometryFeatureLayer:Culvert Groups
# 251             geometry:8:layer:7:VirtualGeometryFeatureLayer:Culvert Barrels
# 252                 geometry:8:layer:8:VirtualGeometryFeatureLayer:Gate Groups
# 253               geometry:8:layer:9:VirtualGeometryFeatureLayer:Gate Openings
# 254             geometry:8:layer:10:VirtualGeometryFeatureLayer:Culvert Groups
# 255            geometry:8:layer:11:VirtualGeometryFeatureLayer:Culvert Barrels
# 256       geometry:8:layer:12:VirtualGeometryFeatureLayer:Rating Curve Outlets
# 257         geometry:8:layer:13:VirtualGeometryFeatureLayer:Outlet Time Series
# 258                geometry:8:layer:14:VirtualGeometryFeatureLayer:Gate Groups
# 259              geometry:8:layer:15:VirtualGeometryFeatureLayer:Gate Openings
# 260             geometry:8:layer:16:VirtualGeometryFeatureLayer:Culvert Groups
# 261            geometry:8:layer:17:VirtualGeometryFeatureLayer:Culvert Barrels
# 262       geometry:8:layer:18:VirtualGeometryFeatureLayer:Rating Curve Outlets
# 263         geometry:8:layer:19:VirtualGeometryFeatureLayer:Outlet Time Series
# 264                    geometry:8:layer:20:SA2DStructureLayer:SA/2D Structures
# 265                geometry:8:layer:21:VirtualGeometryFeatureLayer:Gate Groups
# 266              geometry:8:layer:22:VirtualGeometryFeatureLayer:Gate Openings
# 267             geometry:8:layer:23:VirtualGeometryFeatureLayer:Culvert Groups
# 268            geometry:8:layer:24:VirtualGeometryFeatureLayer:Culvert Barrels
# 269       geometry:8:layer:25:VirtualGeometryFeatureLayer:Rating Curve Outlets
# 270         geometry:8:layer:26:VirtualGeometryFeatureLayer:Outlet Time Series
# 271                                         geometry:8:layer:27:StructureLayer
# 272                                       geometry:8:layer:28:FinalNValueLayer
# 273  geometry:8:layer:29:InterpretationRasterizerLayer:TEMP N-Value Rasterizer
# 274             geometry:8:layer:30:InterpretationRasterizerLayer:Final Values
# 275             geometry:8:layer:31:InterpretationRasterizerLayer:Final Values
#
#                   layer_name                     layer_type checked  \
# 244                                                   RASXS    None
# 245                                           RASD2FlowArea    True
# 246                                      MeshPerimeterLayer    None
# 247                                          MeshPointLayer    True
# 248                                           RASBreakLines    True
# 249                                         MeshRegionLayer    True
# 250           Culvert Groups    VirtualGeometryFeatureLayer    None
# 251          Culvert Barrels    VirtualGeometryFeatureLayer    None
# 252              Gate Groups    VirtualGeometryFeatureLayer    None
# 253            Gate Openings    VirtualGeometryFeatureLayer    None
# 254           Culvert Groups    VirtualGeometryFeatureLayer    None
# 255          Culvert Barrels    VirtualGeometryFeatureLayer    None
# 256     Rating Curve Outlets    VirtualGeometryFeatureLayer    None
# 257       Outlet Time Series    VirtualGeometryFeatureLayer    None
# 258              Gate Groups    VirtualGeometryFeatureLayer    None
# 259            Gate Openings    VirtualGeometryFeatureLayer    None
# 260           Culvert Groups    VirtualGeometryFeatureLayer    None
# 261          Culvert Barrels    VirtualGeometryFeatureLayer    None
# 262     Rating Curve Outlets    VirtualGeometryFeatureLayer    None
# 263       Outlet Time Series    VirtualGeometryFeatureLayer    None
# 264         SA/2D Structures             SA2DStructureLayer    True
# 265              Gate Groups    VirtualGeometryFeatureLayer    None
# 266            Gate Openings    VirtualGeometryFeatureLayer    None
# 267           Culvert Groups    VirtualGeometryFeatureLayer    None
# 268          Culvert Barrels    VirtualGeometryFeatureLayer    None
# 269     Rating Curve Outlets    VirtualGeometryFeatureLayer    None
# 270       Outlet Time Series    VirtualGeometryFeatureLayer    None
# 271                                          StructureLayer    None
# 272                                        FinalNValueLayer    True
# 273  TEMP N-Value Rasterizer  InterpretationRasterizerLayer    None
# 274             Final Values  InterpretationRasterizerLayer    None
# 275             Final Values  InterpretationRasterizerLayer    None
#
#                                                                                                            geometry_hdf_path
# 244  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 245  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 246  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 247  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 248  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 249  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 250  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 251  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 252  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 253  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 254  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 255  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 256  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 257  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 258  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 259  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 260  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 261  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 262  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 263  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 264  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 265  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 266  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 267  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 268  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 269  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 270  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 271  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 272  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 273  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 274  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 275  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# **RASD2FlowArea bounds**
#                                                                                                          geometry_hdf_path  \
# 0  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
#
#       layer_type  \
# 0  RASD2FlowArea
#
#                                                                                                              dataset_paths  \
# 0  [Geometry/2D Flow Areas/Polygon Points, Geometry/2D Flow Areas/BaldEagleCr/Perimeter, Geometry/2D Flow Areas/BaldEag...
#
#           min_x          min_y         max_x          max_y          width  \
# 0  1.965982e+06  289578.114005  2.084790e+06  371007.582554  118808.363928
#
#          height  point_count  has_bounds
# 0  81429.468549        30993        True
#       layer_type  feature_index feature_name feature_type         min_x  \
# 0  RASD2FlowArea              0  BaldEagleCr               1.965982e+06
#
#            min_y         max_x          max_y
# 0  289578.114005  2.084790e+06  371007.582554
# **RASBreakLines bounds**
#                                                                                                          geometry_hdf_path  \
# 0  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
#
#       layer_type                                        dataset_paths  \
# 0  RASBreakLines  [Geometry/2D Flow Area Break Lines/Polyline Points]
#
#          min_x        min_y         max_x          max_y         width  \
# 0  2002361.246  320041.6534  2.064842e+06  352795.015439  62480.513186
#
#          height  point_count  has_bounds
# 0  32753.362039           54        True
#       layer_type  feature_index    feature_name feature_type         min_x  \
# 0  RASBreakLines              0       SayersDam               2.002361e+06
# 1  RASBreakLines              1  RailroadBridge               2.061174e+06
# 2  RASBreakLines              2           Lane1               2.055421e+06
#
#            min_y         max_x          max_y
# 0  320041.653400  2.008475e+06  323707.926800
# 1  351986.964849  2.064842e+06  352795.015439
# 2  350100.243105  2.055630e+06  350364.697058
# **SA2DStructureLayer bounds**
#                                                                                                          geometry_hdf_path  \
# 0  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
#
#            layer_type                            dataset_paths       min_x  \
# 0  SA2DStructureLayer  [Geometry/Structures/Centerline Points]  2002713.51
#
#        min_y         max_x       max_y         width     height  point_count  \
# 0  320226.29  2.063773e+06  356122.481  61059.509557  35896.191          366
#
#    has_bounds
# 0        True
#            layer_type  feature_index      feature_name feature_type  \
# 0  SA2DStructureLayer              0       Highway 120   Connection
# 1  SA2DStructureLayer              1       Highway 150   Connection
# 2  SA2DStructureLayer              2  Highway 150 Lowe   Connection
# 3  SA2DStructureLayer              3       Highway 220   Connection
# 4  SA2DStructureLayer              4     Hwy 220 Upper   Connection
# 5  SA2DStructureLayer              5       Lower Levee   Connection
# 6  SA2DStructureLayer              6      Middle Levee   Connection
# 7  SA2DStructureLayer              7       Mountain Rd   Connection
#
#           min_x          min_y         max_x          max_y
# 0  2.055018e+06  349065.053429  2.055374e+06  349424.354113
# 1  2.036935e+06  344676.056345  2.037221e+06  344713.620738
# 2  2.044745e+06  347580.050645  2.044792e+06  347866.742467
# 3  2.062470e+06  351811.419878  2.063773e+06  351897.646783
# 4  2.052265e+06  347672.704501  2.052616e+06  348354.898113
# 5  2.047901e+06  351772.114764  2.060721e+06  356122.481000
# 6  2.052761e+06  348474.118034  2.061083e+06  351792.461700
# 7  2.023387e+06  333142.559517  2.023735e+06  333168.678259
# **RASXS bounds**
#                                                                                                          geometry_hdf_path  \
# 0  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
#
#   layer_type dataset_paths min_x min_y max_x max_y width height  point_count  \
# 0      RASXS            []  None  None  None  None  None   None            0
#
#    has_bounds
# 0       False
# Empty DataFrame
# Columns: []
# Index: []

# %%
# View setters can be used directly when you already know the bounds.
original_view = RasMap.get_current_view(multi2d)
display(pd.DataFrame([original_view]))

zoomed = RasMap.zoom_to_geometry_layer(
    multi2d,
    geometry_number="03",
    layer_type="RASBreakLines",
    feature_index=0,
)
display(pd.DataFrame([zoomed["view"]]))

# Restore the original view before the screenshot examples below.
if original_view.get("has_current_view"):
    RasMap.set_current_view(
        multi2d,
        min_x=original_view["min_x"],
        min_y=original_view["min_y"],
        max_x=original_view["max_x"],
        max_y=original_view["max_y"],
    )
# Out:
#                                                                                                                rasmap_path  \
# 0  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
#
#                                                                                                            projection_path  \
# 0  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
#
#           min_x         max_x          min_y          max_y          width  \
# 0  1.944200e+06  2.139981e+06  271582.974332  394630.889345  195780.690689
#
#           height  has_current_view
# 0  123047.915013              True
#                                                                                                                rasmap_path  \
# 0  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
#
#                                                                                                            projection_path  \
# 0  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
#
#          min_x        max_x         min_y         max_y     width     height  \
# 0  2000832.852  2010003.216  319125.08505  324624.49515  9170.364  5499.4101
#
#    has_current_view
# 0              True

# %% [markdown]
# ## Screenshot Demonstrations
#
# Each call below writes an audit package and optional PNG into the project's default **RASMapper Screenshots** folder, then displays the screenshot inline. These screenshot cells require Windows with a local HEC-RAS/RASMapper installation.
#
# At this level of development, the notebook demonstrates the API with basic examples. Users should define their own view extents, layer combinations, naming conventions, and capture sequence for programmatic screenshots. A future roadmap item is to add curated capture views aligned with typical report and production figures.

# %%
review_states = {}

review_states["Balde Eagle Creek 1D XS"] = create_demo_review(
    "Balde Eagle Creek",
    title="Bald Eagle Creek 1D Cross Sections",
    geometry_number="01",
    layer_type=["RASXS", "StructureLayer"],
    include_map_layers=False,
    include_results=False,
)
# Out:
# 2026-06-26 19:38:53 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 7.0 at C:\Program Files (x86)\HEC\HEC-RAS\7.0\Ras.exe via filesystem (x86)
# 2026-06-26 19:38:53 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.7 Beta 5 at C:\Program Files (x86)\HEC\HEC-RAS\6.7 Beta 5\Ras.exe via filesystem (x86)
# 2026-06-26 19:38:53 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.6 at C:\Program Files (x86)\HEC\HEC-RAS\6.6\Ras.exe via filesystem (x86)
# 2026-06-26 19:38:53 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.5 at C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe via filesystem (x86)
# 2026-06-26 19:38:53 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.3.1 at C:\Program Files (x86)\HEC\HEC-RAS\6.3.1\Ras.exe via filesystem (x86)
# 2026-06-26 19:38:53 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.2 at C:\Program Files (x86)\HEC\HEC-RAS\6.2\Ras.exe via filesystem (x86)
# 2026-06-26 19:38:53 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.1 at C:\Program Files (x86)\HEC\HEC-RAS\6.1\Ras.exe via filesystem (x86)
# 2026-06-26 19:38:53 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.0 at C:\Program Files (x86)\HEC\HEC-RAS\6.0\Ras.exe via filesystem (x86)
# 2026-06-26 19:38:53 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0.7 at C:\Program Files (x86)\HEC\HEC-RAS\5.0.7\Ras.exe via filesystem (x86)
# 2026-06-26 19:38:53 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0.6 at C:\Program Files (x86)\HEC\HEC-RAS\5.0.6\Ras.exe via filesystem (x86)
# 2026-06-26 19:38:53 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0.5 at C:\Program Files (x86)\HEC\HEC-RAS\5.0.5\Ras.exe via filesystem (x86)
# 2026-06-26 19:38:53 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0.4 at C:\Program Files (x86)\HEC\HEC-RAS\5.0.4\Ras.exe via filesystem (x86)
# 2026-06-26 19:38:53 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0.3 at C:\Program Files (x86)\HEC\HEC-RAS\5.0.3\Ras.exe via filesystem (x86)
# 2026-06-26 19:38:53 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0.1 at C:\Program Files (x86)\HEC\HEC-RAS\5.0.1\Ras.exe via filesystem (x86)
# 2026-06-26 19:38:53 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0 at C:\Program Files (x86)\HEC\HEC-RAS\5.0\Ras.exe via filesystem (x86)
# 2026-06-26 19:38:53 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 4.1.0 at C:\Program Files (x86)\HEC\HEC-RAS\4.1.0\Ras.exe via filesystem (x86)
# 2026-06-26 19:38:53 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 4.0 at C:\Program Files (x86)\HEC\HEC-RAS\4.0\Ras.exe via filesystem (x86)
# 2026-06-26 19:38:53 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 7.0.1 at C:\Program Files (x86)\HEC\HEC-RAS\7.0.1\Ras.exe via filesystem (x86)
# 2026-06-26 19:38:53 - ras_commander.RasUtils - INFO - Discovered 18 installed HEC-RAS version(s)
# 2026-06-26 19:38:53 - ras_commander.RasPrj - INFO - HEC-RAS 6.6 found via version discovery: C:\Program Files (x86)\HEC\HEC-RAS\6.6\Ras.exe
# 2026-06-26 19:39:02 - ras_commander.gui.screenshots - INFO - Screenshot saved: <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Balde Eagle Creek_rasmapper_demo\RASMapper Screenshots\Bald_Eagle_Creek_1D_Cross_Sections.png
# ### Bald Eagle Creek 1D Cross Sections
# Project: `<workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Balde Eagle Creek_rasmapper_demo`
# Review folder: `<workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Balde Eagle Creek_rasmapper_demo\RASMapper Screenshots`
#                              code  passed  \
# 0                   rasmap_exists    True
# 1           geometry_layers_found    True
# 2  selected_geometry_layers_found    True
# 3    selected_geometry_hdf_exists    True
#
#                                                                                                                    message
# 0  RASMapper file exists: <workspace>\examples\working\notebook_runs\122_rasmapper_...
# 1                                                                               Geometry layers were found in the .rasmap.
# 2                                                                                   Selected geometry layer(s) were found.
# 3                                                                                 Selected geometry layer HDF files exist.
# **Screenshot:** `<workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Balde Eagle Creek_rasmapper_demo\RASMapper Screenshots\Bald_Eagle_Creek_1D_Cross_Sections.png`

# %%
review_states["Muncie 2D structures"] = create_demo_review(
    "Muncie",
    title="Muncie 2D Flow Area and Structures",
    geometry_number="04",
    layer_type=["RASD2FlowArea", "StructureLayer"],
    terrain_name=first_terrain_name(Path(projects["Muncie"]), "TerrainWithChannel"),
    feature_index=0,
    map_layer_category=maybe_map_category(Path(projects["Muncie"]), ["land_classification", "reference"]),
)
# Out:
# 2026-06-26 19:39:02 - ras_commander.RasMap - INFO - Found 5 map layers in .rasmap
# 2026-06-26 19:39:03 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 7.0 at C:\Program Files (x86)\HEC\HEC-RAS\7.0\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:03 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.7 Beta 5 at C:\Program Files (x86)\HEC\HEC-RAS\6.7 Beta 5\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:03 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.6 at C:\Program Files (x86)\HEC\HEC-RAS\6.6\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:03 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.5 at C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:03 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.3.1 at C:\Program Files (x86)\HEC\HEC-RAS\6.3.1\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:03 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.2 at C:\Program Files (x86)\HEC\HEC-RAS\6.2\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:03 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.1 at C:\Program Files (x86)\HEC\HEC-RAS\6.1\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:03 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.0 at C:\Program Files (x86)\HEC\HEC-RAS\6.0\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:03 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0.7 at C:\Program Files (x86)\HEC\HEC-RAS\5.0.7\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:03 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0.6 at C:\Program Files (x86)\HEC\HEC-RAS\5.0.6\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:03 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0.5 at C:\Program Files (x86)\HEC\HEC-RAS\5.0.5\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:03 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0.4 at C:\Program Files (x86)\HEC\HEC-RAS\5.0.4\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:03 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0.3 at C:\Program Files (x86)\HEC\HEC-RAS\5.0.3\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:03 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0.1 at C:\Program Files (x86)\HEC\HEC-RAS\5.0.1\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:03 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0 at C:\Program Files (x86)\HEC\HEC-RAS\5.0\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:03 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 4.1.0 at C:\Program Files (x86)\HEC\HEC-RAS\4.1.0\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:03 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 4.0 at C:\Program Files (x86)\HEC\HEC-RAS\4.0\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:03 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 7.0.1 at C:\Program Files (x86)\HEC\HEC-RAS\7.0.1\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:03 - ras_commander.RasUtils - INFO - Discovered 18 installed HEC-RAS version(s)
# 2026-06-26 19:39:03 - ras_commander.RasPrj - INFO - HEC-RAS 6.6 found via version discovery: C:\Program Files (x86)\HEC\HEC-RAS\6.6\Ras.exe
# 2026-06-26 19:39:12 - ras_commander.gui.screenshots - INFO - Screenshot saved: <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Muncie_rasmapper_demo\RASMapper Screenshots\Muncie_2D_Flow_Area_and_Structures.png
# ### Muncie 2D Flow Area and Structures
# Project: `<workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Muncie_rasmapper_demo`
# Review folder: `<workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Muncie_rasmapper_demo\RASMapper Screenshots`
#                                code  passed  \
# 0                     rasmap_exists    True
# 1             geometry_layers_found    True
# 2    selected_geometry_layers_found    True
# 3      selected_geometry_hdf_exists    True
# 4  selected_geometry_features_found    True
# 5         selected_map_layers_found    True
# 6            selected_terrain_found    True
# 7                     geojson_wgs84    True
#
#                                                                                                                    message
# 0  RASMapper file exists: <workspace>\examples\working\notebook_runs\122_rasmapper_...
# 1                                                                               Geometry layers were found in the .rasmap.
# 2                                                                                   Selected geometry layer(s) were found.
# 3                                                                                 Selected geometry layer HDF files exist.
# 4                                                                                 Selected geometry feature(s) were found.
# 5                                                                                        Selected map layer(s) were found.
# 6                                                                        Selected terrain layer exists: TerrainWithChannel
# 7                                                                    GeoJSON layer is WGS84-compatible: Demo WGS84 GeoJSON
# **Screenshot:** `<workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Muncie_rasmapper_demo\RASMapper Screenshots\Muncie_2D_Flow_Area_and_Structures.png`

# %%
review_states["BaldEagleCrkMulti2D breaklines"] = create_demo_review(
    "BaldEagleCrkMulti2D",
    title="Bald Eagle Multi2D Breaklines and SA2D Structures",
    geometry_number="03",
    layer_type=["RASD2FlowArea", "RASBreakLines", "SA2DStructureLayer", "MeshRegionLayer"],
    terrain_name=first_terrain_name(Path(projects["BaldEagleCrkMulti2D"])),
    feature_index=0,
    map_layer_category=maybe_map_category(Path(projects["BaldEagleCrkMulti2D"]), ["land_classification", "basemap"]),
)
# Out:
# 2026-06-26 19:39:12 - ras_commander.RasMap - INFO - Found 4 map layers in .rasmap
# 2026-06-26 19:39:13 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 7.0 at C:\Program Files (x86)\HEC\HEC-RAS\7.0\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:13 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.7 Beta 5 at C:\Program Files (x86)\HEC\HEC-RAS\6.7 Beta 5\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:13 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.6 at C:\Program Files (x86)\HEC\HEC-RAS\6.6\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:13 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.5 at C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:13 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.3.1 at C:\Program Files (x86)\HEC\HEC-RAS\6.3.1\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:13 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.2 at C:\Program Files (x86)\HEC\HEC-RAS\6.2\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:13 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.1 at C:\Program Files (x86)\HEC\HEC-RAS\6.1\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:13 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.0 at C:\Program Files (x86)\HEC\HEC-RAS\6.0\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:13 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0.7 at C:\Program Files (x86)\HEC\HEC-RAS\5.0.7\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:13 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0.6 at C:\Program Files (x86)\HEC\HEC-RAS\5.0.6\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:13 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0.5 at C:\Program Files (x86)\HEC\HEC-RAS\5.0.5\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:13 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0.4 at C:\Program Files (x86)\HEC\HEC-RAS\5.0.4\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:13 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0.3 at C:\Program Files (x86)\HEC\HEC-RAS\5.0.3\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:13 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0.1 at C:\Program Files (x86)\HEC\HEC-RAS\5.0.1\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:13 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0 at C:\Program Files (x86)\HEC\HEC-RAS\5.0\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:13 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 4.1.0 at C:\Program Files (x86)\HEC\HEC-RAS\4.1.0\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:13 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 4.0 at C:\Program Files (x86)\HEC\HEC-RAS\4.0\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:13 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 7.0.1 at C:\Program Files (x86)\HEC\HEC-RAS\7.0.1\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:13 - ras_commander.RasUtils - INFO - Discovered 18 installed HEC-RAS version(s)
# 2026-06-26 19:39:13 - ras_commander.RasPrj - INFO - HEC-RAS 6.6 found via version discovery: C:\Program Files (x86)\HEC\HEC-RAS\6.6\Ras.exe
# 2026-06-26 19:39:22 - ras_commander.gui.screenshots - INFO - Screenshot saved: <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagleCrkMulti2D_rasmapper_demo\RASMapper Screenshots\Bald_Eagle_Multi2D_Breaklines_and_SA2D_Structures.png
# ### Bald Eagle Multi2D Breaklines and SA2D Structures
# Project: `<workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagleCrkMulti2D_rasmapper_demo`
# Review folder: `<workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagleCrkMulti2D_rasmapper_demo\RASMapper Screenshots`
#                                code  passed  \
# 0                     rasmap_exists    True
# 1             geometry_layers_found    True
# 2    selected_geometry_layers_found    True
# 3      selected_geometry_hdf_exists    True
# 4  selected_geometry_features_found    True
# 5         selected_map_layers_found    True
# 6            selected_terrain_found    True
#
#                                                                                                                    message
# 0  RASMapper file exists: <workspace>\examples\working\notebook_runs\122_rasmapper_...
# 1                                                                               Geometry layers were found in the .rasmap.
# 2                                                                                   Selected geometry layer(s) were found.
# 3                                                                                 Selected geometry layer HDF files exist.
# 4                                                                                 Selected geometry feature(s) were found.
# 5                                                                                        Selected map layer(s) were found.
# 6                                                                                 Selected terrain layer exists: Terrain50
# **Screenshot:** `<workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagleCrkMulti2D_rasmapper_demo\RASMapper Screenshots\Bald_Eagle_Multi2D_Breaklines_and_SA2D_Structures.png`

# %%
review_states["Davis storm system"] = create_demo_review(
    "Davis",
    title="Davis Pipes Pumps Storage and 2D Area",
    geometry_number="02",
    layer_type=[
        "RASD2FlowArea",
        "RASPipeNetworks",
        "RASPipeNodes",
        "RASPipeLinks",
        "PumpStationLayer",
        "PumpLayer",
        "RASStorageArea",
        "StructureLayer",
    ],
    terrain_name=first_terrain_name(Path(projects["Davis"])),
)
# Out:
# 2026-06-26 19:39:22 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 7.0 at C:\Program Files (x86)\HEC\HEC-RAS\7.0\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:22 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.7 Beta 5 at C:\Program Files (x86)\HEC\HEC-RAS\6.7 Beta 5\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:22 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.6 at C:\Program Files (x86)\HEC\HEC-RAS\6.6\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:22 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.5 at C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:22 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.3.1 at C:\Program Files (x86)\HEC\HEC-RAS\6.3.1\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:22 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.2 at C:\Program Files (x86)\HEC\HEC-RAS\6.2\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:22 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.1 at C:\Program Files (x86)\HEC\HEC-RAS\6.1\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:22 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.0 at C:\Program Files (x86)\HEC\HEC-RAS\6.0\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:22 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0.7 at C:\Program Files (x86)\HEC\HEC-RAS\5.0.7\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:22 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0.6 at C:\Program Files (x86)\HEC\HEC-RAS\5.0.6\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:22 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0.5 at C:\Program Files (x86)\HEC\HEC-RAS\5.0.5\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:22 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0.4 at C:\Program Files (x86)\HEC\HEC-RAS\5.0.4\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:22 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0.3 at C:\Program Files (x86)\HEC\HEC-RAS\5.0.3\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:22 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0.1 at C:\Program Files (x86)\HEC\HEC-RAS\5.0.1\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:22 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0 at C:\Program Files (x86)\HEC\HEC-RAS\5.0\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:22 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 4.1.0 at C:\Program Files (x86)\HEC\HEC-RAS\4.1.0\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:22 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 4.0 at C:\Program Files (x86)\HEC\HEC-RAS\4.0\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:22 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 7.0.1 at C:\Program Files (x86)\HEC\HEC-RAS\7.0.1\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:22 - ras_commander.RasUtils - INFO - Discovered 18 installed HEC-RAS version(s)
# 2026-06-26 19:39:22 - ras_commander.RasPrj - INFO - HEC-RAS 6.6 found via version discovery: C:\Program Files (x86)\HEC\HEC-RAS\6.6\Ras.exe
# 2026-06-26 19:39:32 - ras_commander.gui.screenshots - INFO - Screenshot saved: <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Davis_rasmapper_demo\RASMapper Screenshots\Davis_Pipes_Pumps_Storage_and_2D_Area.png
# ### Davis Pipes Pumps Storage and 2D Area
# Project: `<workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Davis_rasmapper_demo`
# Review folder: `<workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Davis_rasmapper_demo\RASMapper Screenshots`
#                              code  passed  \
# 0                   rasmap_exists    True
# 1           geometry_layers_found    True
# 2  selected_geometry_layers_found    True
# 3    selected_geometry_hdf_exists    True
# 4          selected_terrain_found    True
#
#                                                                                                                    message
# 0  RASMapper file exists: <workspace>\examples\working\notebook_runs\122_rasmapper_...
# 1                                                                               Geometry layers were found in the .rasmap.
# 2                                                                                   Selected geometry layer(s) were found.
# 3                                                                                 Selected geometry layer HDF files exist.
# 4                                                                               Selected terrain layer exists: Terrain (1)
# **Screenshot:** `<workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Davis_rasmapper_demo\RASMapper Screenshots\Davis_Pipes_Pumps_Storage_and_2D_Area.png`

# %%
review_states["New Orleans metro"] = create_demo_review(
    "NewOrleansMetro",
    title="New Orleans Metro Pipes Pumps Breaklines and SA2D",
    geometry_number="02",
    layer_type=[
        "RASD2FlowArea",
        "RASBreakLines",
        "SA2DStructureLayer",
        "RASPipeNetworks",
        "RASPipeNodes",
        "RASPipeLinks",
        "PumpStationLayer",
        "PumpLayer",
    ],
    terrain_name=first_terrain_name(Path(projects["NewOrleansMetro"])),
    feature_index=0,
    map_layer_category=maybe_map_category(Path(projects["NewOrleansMetro"]), ["land_classification", "basemap"]),
)
# Out:
# 2026-06-26 19:39:32 - ras_commander.RasMap - INFO - Found 2 map layers in .rasmap
# 2026-06-26 19:39:32 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 7.0 at C:\Program Files (x86)\HEC\HEC-RAS\7.0\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:32 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.7 Beta 5 at C:\Program Files (x86)\HEC\HEC-RAS\6.7 Beta 5\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:32 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.6 at C:\Program Files (x86)\HEC\HEC-RAS\6.6\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:32 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.5 at C:\Program Files (x86)\HEC\HEC-RAS\6.5\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:32 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.3.1 at C:\Program Files (x86)\HEC\HEC-RAS\6.3.1\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:32 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.2 at C:\Program Files (x86)\HEC\HEC-RAS\6.2\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:32 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.1 at C:\Program Files (x86)\HEC\HEC-RAS\6.1\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:32 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 6.0 at C:\Program Files (x86)\HEC\HEC-RAS\6.0\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:32 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0.7 at C:\Program Files (x86)\HEC\HEC-RAS\5.0.7\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:32 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0.6 at C:\Program Files (x86)\HEC\HEC-RAS\5.0.6\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:32 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0.5 at C:\Program Files (x86)\HEC\HEC-RAS\5.0.5\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:32 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0.4 at C:\Program Files (x86)\HEC\HEC-RAS\5.0.4\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:32 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0.3 at C:\Program Files (x86)\HEC\HEC-RAS\5.0.3\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:32 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0.1 at C:\Program Files (x86)\HEC\HEC-RAS\5.0.1\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:32 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 5.0 at C:\Program Files (x86)\HEC\HEC-RAS\5.0\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:32 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 4.1.0 at C:\Program Files (x86)\HEC\HEC-RAS\4.1.0\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:32 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 4.0 at C:\Program Files (x86)\HEC\HEC-RAS\4.0\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:32 - ras_commander.RasUtils - INFO - Discovered HEC-RAS 7.0.1 at C:\Program Files (x86)\HEC\HEC-RAS\7.0.1\Ras.exe via filesystem (x86)
# 2026-06-26 19:39:32 - ras_commander.RasUtils - INFO - Discovered 18 installed HEC-RAS version(s)
# 2026-06-26 19:39:32 - ras_commander.RasPrj - INFO - HEC-RAS 6.6 found via version discovery: C:\Program Files (x86)\HEC\HEC-RAS\6.6\Ras.exe
# 2026-06-26 19:39:41 - ras_commander.gui.screenshots - INFO - Screenshot saved: <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\NewOrleansMetro_rasmapper_demo\RASMapper Screenshots\New_Orleans_Metro_Pipes_Pumps_Breaklines_and_SA2D.png
# ### New Orleans Metro Pipes Pumps Breaklines and SA2D
# Project: `<workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\NewOrleansMetro_rasmapper_demo`
# Review folder: `<workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\NewOrleansMetro_rasmapper_demo\RASMapper Screenshots`
#                                code  passed  \
# 0                     rasmap_exists    True
# 1             geometry_layers_found    True
# 2    selected_geometry_layers_found    True
# 3      selected_geometry_hdf_exists    True
# 4  selected_geometry_features_found    True
# 5         selected_map_layers_found    True
# 6            selected_terrain_found    True
#
#                                                                                                                    message
# 0  RASMapper file exists: <workspace>\examples\working\notebook_runs\122_rasmapper_...
# 1                                                                               Geometry layers were found in the .rasmap.
# 2                                                                                   Selected geometry layer(s) were found.
# 3                                                                                 Selected geometry layer HDF files exist.
# 4                                                                                 Selected geometry feature(s) were found.
# 5                                                                                        Selected map layer(s) were found.
# 6                                                                 Selected terrain layer exists: NGOMTopoBathy-PCCPSurveys
# **Screenshot:** `<workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\NewOrleansMetro_rasmapper_demo\RASMapper Screenshots\New_Orleans_Metro_Pipes_Pumps_Breaklines_and_SA2D.png`

# %% [markdown]
# ## Result Layer State
#
# Many fresh example projects do not have populated RASMapper result layers until results are generated or maps are stored. The functions still provide a uniform tree API: list what exists, hide all results for clean geometry figures, or show selected result context when present.

# %%
result_summary = []
for name, project_path in projects.items():
    result_layers = RasMap.list_result_layers(project_path)
    result_summary.append({"project": name, "result_rows": len(result_layers)})
    if not result_layers.empty:
        RasMap.set_result_layer_visibility(project_path, checked=False)
        first_plan = result_layers["plan_name"].dropna().iloc[0]
        RasMap.set_result_layer_visibility(project_path, plan_name=first_plan, checked=True, exclusive=True)
        display(Markdown(f"### {name}: result layers"))
        compact_display(RasMap.list_result_layers(project_path), max_rows=20)

display(pd.DataFrame(result_summary))
# Out:
# ### Davis: result layers
#                                                                 layer_id  \
# 0                                                               result:0
# 1                   result:0:layer:0:RASEventConditions:Event Conditions
# 2                                           result:0:layer:1:RASGeometry
# 3                                               result:0:layer:1.0:RASXS
# 4          result:0:layer:1.1:VirtualGeometryFeatureLayer:Culvert Groups
# 5         result:0:layer:1.2:VirtualGeometryFeatureLayer:Culvert Barrels
# 6             result:0:layer:1.3:VirtualGeometryFeatureLayer:Gate Groups
# 7           result:0:layer:1.4:VirtualGeometryFeatureLayer:Gate Openings
# 8          result:0:layer:1.5:VirtualGeometryFeatureLayer:Culvert Groups
# 9         result:0:layer:1.6:VirtualGeometryFeatureLayer:Culvert Barrels
# 10   result:0:layer:1.7:VirtualGeometryFeatureLayer:Rating Curve Outlets
# 11     result:0:layer:1.8:VirtualGeometryFeatureLayer:Outlet Time Series
# 12            result:0:layer:1.9:VirtualGeometryFeatureLayer:Gate Groups
# 13         result:0:layer:1.10:VirtualGeometryFeatureLayer:Gate Openings
# 14        result:0:layer:1.11:VirtualGeometryFeatureLayer:Culvert Groups
# 15       result:0:layer:1.12:VirtualGeometryFeatureLayer:Culvert Barrels
# 16  result:0:layer:1.13:VirtualGeometryFeatureLayer:Rating Curve Outlets
# 17    result:0:layer:1.14:VirtualGeometryFeatureLayer:Outlet Time Series
# 18           result:0:layer:1.15:VirtualGeometryFeatureLayer:Gate Groups
# 19         result:0:layer:1.16:VirtualGeometryFeatureLayer:Gate Openings
#
#         category                  plan_name               plan_filename  \
# 0    result_plan  Full System ROM with Pump  .\DavisStormSystem.p02.hdf
# 1   result_layer  Full System ROM with Pump
# 2   result_layer  Full System ROM with Pump
# 3   result_layer  Full System ROM with Pump
# 4   result_layer  Full System ROM with Pump
# 5   result_layer  Full System ROM with Pump
# 6   result_layer  Full System ROM with Pump
# 7   result_layer  Full System ROM with Pump
# 8   result_layer  Full System ROM with Pump
# 9   result_layer  Full System ROM with Pump
# 10  result_layer  Full System ROM with Pump
# 11  result_layer  Full System ROM with Pump
# 12  result_layer  Full System ROM with Pump
# 13  result_layer  Full System ROM with Pump
# 14  result_layer  Full System ROM with Pump
# 15  result_layer  Full System ROM with Pump
# 16  result_layer  Full System ROM with Pump
# 17  result_layer  Full System ROM with Pump
# 18  result_layer  Full System ROM with Pump
# 19  result_layer  Full System ROM with Pump
#
#                    layer_name                   layer_type  checked expanded  \
# 0   Full System ROM with Pump                   RASResults     True     True
# 1            Event Conditions           RASEventConditions     True     None
# 2                                              RASGeometry     True     None
# 3                                                    RASXS     True     None
# 4              Culvert Groups  VirtualGeometryFeatureLayer     True     None
# 5             Culvert Barrels  VirtualGeometryFeatureLayer     True     None
# 6                 Gate Groups  VirtualGeometryFeatureLayer     True     None
# 7               Gate Openings  VirtualGeometryFeatureLayer     True     None
# 8              Culvert Groups  VirtualGeometryFeatureLayer     True     None
# 9             Culvert Barrels  VirtualGeometryFeatureLayer     True     None
# 10       Rating Curve Outlets  VirtualGeometryFeatureLayer     True     None
# 11         Outlet Time Series  VirtualGeometryFeatureLayer     True     None
# 12                Gate Groups  VirtualGeometryFeatureLayer     True     None
# 13              Gate Openings  VirtualGeometryFeatureLayer     True     None
# 14             Culvert Groups  VirtualGeometryFeatureLayer     True     None
# 15            Culvert Barrels  VirtualGeometryFeatureLayer     True     None
# 16       Rating Curve Outlets  VirtualGeometryFeatureLayer     True     None
# 17         Outlet Time Series  VirtualGeometryFeatureLayer     True     None
# 18                Gate Groups  VirtualGeometryFeatureLayer     True     None
# 19              Gate Openings  VirtualGeometryFeatureLayer     True     None
#
#     result_index layer_index  depth  \
# 0              0                  0
# 1              0           0      1
# 2              0           1      1
# 3              0         1.0      2
# 4              0         1.1      2
# 5              0         1.2      2
# 6              0         1.3      2
# 7              0         1.4      2
# 8              0         1.5      2
# 9              0         1.6      2
# 10             0         1.7      2
# 11             0         1.8      2
# 12             0         1.9      2
# 13             0        1.10      2
# 14             0        1.11      2
# 15             0        1.12      2
# 16             0        1.13      2
# 17             0        1.14      2
# 18             0        1.15      2
# 19             0        1.16      2
#
#                                          layer_path  \
# 0                         Full System ROM with Pump
# 1        Full System ROM with Pump/Event Conditions
# 2                        Full System ROM with Pump/
# 3                       Full System ROM with Pump//
# 4         Full System ROM with Pump//Culvert Groups
# 5        Full System ROM with Pump//Culvert Barrels
# 6            Full System ROM with Pump//Gate Groups
# 7          Full System ROM with Pump//Gate Openings
# 8         Full System ROM with Pump//Culvert Groups
# 9        Full System ROM with Pump//Culvert Barrels
# 10  Full System ROM with Pump//Rating Curve Outlets
# 11    Full System ROM with Pump//Outlet Time Series
# 12           Full System ROM with Pump//Gate Groups
# 13         Full System ROM with Pump//Gate Openings
# 14        Full System ROM with Pump//Culvert Groups
# 15       Full System ROM with Pump//Culvert Barrels
# 16  Full System ROM with Pump//Rating Curve Outlets
# 17    Full System ROM with Pump//Outlet Time Series
# 18           Full System ROM with Pump//Gate Groups
# 19         Full System ROM with Pump//Gate Openings
#
#                       filename  parent_identifiers profile_index
# 0   .\DavisStormSystem.p02.hdf
# 1   .\DavisStormSystem.p02.hdf
# 2   .\DavisStormSystem.p02.hdf
# 3
# 4
# 5                                 Bridges/Culverts
# 6
# 7                                Inline Structures
# 8
# 9                                Inline Structures
# 10                               Inline Structures
# 11                               Inline Structures
# 12
# 13                              Lateral Structures
# 14
# 15                              Lateral Structures
# 16                              Lateral Structures
# 17                              Lateral Structures
# 18
# 19                               SA/2D Connections
# ### NewOrleansMetro: result layers
#                                                                 layer_id  \
# 0                                                               result:0
# 1                   result:0:layer:0:RASEventConditions:Event Conditions
# 2                                           result:0:layer:1:RASGeometry
# 3                                               result:0:layer:1.0:RASXS
# 4          result:0:layer:1.1:VirtualGeometryFeatureLayer:Culvert Groups
# 5         result:0:layer:1.2:VirtualGeometryFeatureLayer:Culvert Barrels
# 6             result:0:layer:1.3:VirtualGeometryFeatureLayer:Gate Groups
# 7           result:0:layer:1.4:VirtualGeometryFeatureLayer:Gate Openings
# 8          result:0:layer:1.5:VirtualGeometryFeatureLayer:Culvert Groups
# 9         result:0:layer:1.6:VirtualGeometryFeatureLayer:Culvert Barrels
# 10   result:0:layer:1.7:VirtualGeometryFeatureLayer:Rating Curve Outlets
# 11     result:0:layer:1.8:VirtualGeometryFeatureLayer:Outlet Time Series
# 12            result:0:layer:1.9:VirtualGeometryFeatureLayer:Gate Groups
# 13         result:0:layer:1.10:VirtualGeometryFeatureLayer:Gate Openings
# 14        result:0:layer:1.11:VirtualGeometryFeatureLayer:Culvert Groups
# 15       result:0:layer:1.12:VirtualGeometryFeatureLayer:Culvert Barrels
# 16  result:0:layer:1.13:VirtualGeometryFeatureLayer:Rating Curve Outlets
# 17    result:0:layer:1.14:VirtualGeometryFeatureLayer:Outlet Time Series
# 18           result:0:layer:1.15:VirtualGeometryFeatureLayer:Gate Groups
# 19         result:0:layer:1.16:VirtualGeometryFeatureLayer:Gate Openings
#
#         category                 plan_name              plan_filename  \
# 0    result_plan  2D Surface Model w Pipes  .\NewOrleansMetro.p01.hdf
# 1   result_layer  2D Surface Model w Pipes
# 2   result_layer  2D Surface Model w Pipes
# 3   result_layer  2D Surface Model w Pipes
# 4   result_layer  2D Surface Model w Pipes
# 5   result_layer  2D Surface Model w Pipes
# 6   result_layer  2D Surface Model w Pipes
# 7   result_layer  2D Surface Model w Pipes
# 8   result_layer  2D Surface Model w Pipes
# 9   result_layer  2D Surface Model w Pipes
# 10  result_layer  2D Surface Model w Pipes
# 11  result_layer  2D Surface Model w Pipes
# 12  result_layer  2D Surface Model w Pipes
# 13  result_layer  2D Surface Model w Pipes
# 14  result_layer  2D Surface Model w Pipes
# 15  result_layer  2D Surface Model w Pipes
# 16  result_layer  2D Surface Model w Pipes
# 17  result_layer  2D Surface Model w Pipes
# 18  result_layer  2D Surface Model w Pipes
# 19  result_layer  2D Surface Model w Pipes
#
#                   layer_name                   layer_type  checked expanded  \
# 0   2D Surface Model w Pipes                   RASResults     True     True
# 1           Event Conditions           RASEventConditions     True     None
# 2                                             RASGeometry     True     None
# 3                                                   RASXS     True     None
# 4             Culvert Groups  VirtualGeometryFeatureLayer     True     None
# 5            Culvert Barrels  VirtualGeometryFeatureLayer     True     None
# 6                Gate Groups  VirtualGeometryFeatureLayer     True     None
# 7              Gate Openings  VirtualGeometryFeatureLayer     True     None
# 8             Culvert Groups  VirtualGeometryFeatureLayer     True     None
# 9            Culvert Barrels  VirtualGeometryFeatureLayer     True     None
# 10      Rating Curve Outlets  VirtualGeometryFeatureLayer     True     None
# 11        Outlet Time Series  VirtualGeometryFeatureLayer     True     None
# 12               Gate Groups  VirtualGeometryFeatureLayer     True     None
# 13             Gate Openings  VirtualGeometryFeatureLayer     True     None
# 14            Culvert Groups  VirtualGeometryFeatureLayer     True     None
# 15           Culvert Barrels  VirtualGeometryFeatureLayer     True     None
# 16      Rating Curve Outlets  VirtualGeometryFeatureLayer     True     None
# 17        Outlet Time Series  VirtualGeometryFeatureLayer     True     None
# 18               Gate Groups  VirtualGeometryFeatureLayer     True     None
# 19             Gate Openings  VirtualGeometryFeatureLayer     True     None
#
#     result_index layer_index  depth  \
# 0              0                  0
# 1              0           0      1
# 2              0           1      1
# 3              0         1.0      2
# 4              0         1.1      2
# 5              0         1.2      2
# 6              0         1.3      2
# 7              0         1.4      2
# 8              0         1.5      2
# 9              0         1.6      2
# 10             0         1.7      2
# 11             0         1.8      2
# 12             0         1.9      2
# 13             0        1.10      2
# 14             0        1.11      2
# 15             0        1.12      2
# 16             0        1.13      2
# 17             0        1.14      2
# 18             0        1.15      2
# 19             0        1.16      2
#
#                                         layer_path                   filename  \
# 0                         2D Surface Model w Pipes  .\NewOrleansMetro.p01.hdf
# 1        2D Surface Model w Pipes/Event Conditions  .\NewOrleansMetro.p01.hdf
# 2                        2D Surface Model w Pipes/  .\NewOrleansMetro.p01.hdf
# 3                       2D Surface Model w Pipes//
# 4         2D Surface Model w Pipes//Culvert Groups
# 5        2D Surface Model w Pipes//Culvert Barrels
# 6            2D Surface Model w Pipes//Gate Groups
# 7          2D Surface Model w Pipes//Gate Openings
# 8         2D Surface Model w Pipes//Culvert Groups
# 9        2D Surface Model w Pipes//Culvert Barrels
# 10  2D Surface Model w Pipes//Rating Curve Outlets
# 11    2D Surface Model w Pipes//Outlet Time Series
# 12           2D Surface Model w Pipes//Gate Groups
# 13         2D Surface Model w Pipes//Gate Openings
# 14        2D Surface Model w Pipes//Culvert Groups
# 15       2D Surface Model w Pipes//Culvert Barrels
# 16  2D Surface Model w Pipes//Rating Curve Outlets
# 17    2D Surface Model w Pipes//Outlet Time Series
# 18           2D Surface Model w Pipes//Gate Groups
# 19         2D Surface Model w Pipes//Gate Openings
#
#     parent_identifiers profile_index
# 0
# 1
# 2
# 3
# 4
# 5     Bridges/Culverts
# 6
# 7    Inline Structures
# 8
# 9    Inline Structures
# 10   Inline Structures
# 11   Inline Structures
# 12
# 13  Lateral Structures
# 14
# 15  Lateral Structures
# 16  Lateral Structures
# 17  Lateral Structures
# 18
# 19   SA/2D Connections
#                project  result_rows
# 0    Balde Eagle Creek            0
# 1               Muncie            0
# 2  BaldEagleCrkMulti2D            0
# 3                Davis           41
# 4      NewOrleansMetro           41

# %% [markdown]
# ## Low-Level RASMapper Window Primitives
#
# `create_spatial_review_package()` is the recommended public workflow. The lower-level functions are exposed for custom orchestration when you want to configure `.rasmap` state yourself, open standalone RASMapper, capture a visible window, and close the process by PID.

# %%
if RUN_LOW_LEVEL_CAPTURE and CAPTURE_SNAPSHOTS:
    project_path = Path(projects["Muncie"])
    screenshot_path = project_path / "RASMapper Screenshots" / "low_level_manual_capture.png"
    screenshot_path.parent.mkdir(exist_ok=True)

    process = RasMap.open_rasmapper(project_path, ras_version=RAS_VERSION)
    try:
        captured = RasMap.capture_rasmapper_snapshot(
            pid=process.pid,
            output_path=screenshot_path,
            delay_seconds=SNAPSHOT_DELAY_SECONDS,
            timeout_seconds=SNAPSHOT_TIMEOUT_SECONDS,
        )
        if captured:
            display(Image(filename=str(captured)))
    finally:
        RasMap.close_rasmapper(pid=process.pid)
else:
    display(Markdown("Low-level capture skipped. Set `RUN_LOW_LEVEL_CAPTURE = True` in the first cell to run it."))
# Out:
# Low-level capture skipped. Set `RUN_LOW_LEVEL_CAPTURE = True` in the first cell to run it.

# %% [markdown]
# ## Review Artifacts
#
# The screenshot folder also contains CSV and JSON artifacts that agents or engineers can review without reopening RASMapper.

# %%
artifact_rows = []
for label, state in review_states.items():
    artifacts = state.get("artifacts", {})
    artifact_rows.append(
        {
            "review": label,
            "passed": state.get("passed"),
            "output_dir": state.get("output_dir"),
            "snapshot": state.get("snapshot", {}).get("path"),
            "geometry_layers": artifacts.get("geometry_layers"),
            "geometry_features": artifacts.get("geometry_features"),
            "map_layers": artifacts.get("map_layers"),
            "review_state": artifacts.get("review_state"),
        }
    )

display(pd.DataFrame(artifact_rows))
# Out:
#                            review  passed  \
# 0         Balde Eagle Creek 1D XS    True
# 1            Muncie 2D structures    True
# 2  BaldEagleCrkMulti2D breaklines    True
# 3              Davis storm system    True
# 4               New Orleans metro    True
#
#                                                                                                                 output_dir  \
# 0  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Balde Ea...
# 1  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Muncie_r...
# 2  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 3  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Davis_ra...
# 4  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\NewOrlea...
#
#                                                                                                                   snapshot  \
# 0  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Balde Ea...
# 1  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Muncie_r...
# 2  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 3  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Davis_ra...
# 4  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\NewOrlea...
#
#                                                                                                            geometry_layers  \
# 0  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Balde Ea...
# 1  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Muncie_r...
# 2  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 3  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Davis_ra...
# 4  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\NewOrlea...
#
#                                                                                                          geometry_features  \
# 0  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Balde Ea...
# 1  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Muncie_r...
# 2  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 3  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Davis_ra...
# 4  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\NewOrlea...
#
#                                                                                                                 map_layers  \
# 0  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Balde Ea...
# 1  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Muncie_r...
# 2  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 3  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Davis_ra...
# 4  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\NewOrlea...
#
#                                                                                                               review_state
# 0  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Balde Ea...
# 1  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Muncie_r...
# 2  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\BaldEagl...
# 3  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\Davis_ra...
# 4  <workspace>\examples\working\notebook_runs\122_rasmapper_spatial_review\NewOrlea...
